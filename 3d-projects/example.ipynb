# %% [markdown]
# # Example

# %%
%clear
%command xvfb-run openscad
# Out:
# SCAD code buffer has been cleared
# The display command is 'xvfb-run openscad'

# %%
%lsmagic
# Out:
# Available Commands: %clear %display %displayCode %%display %%displayCode %mime %command %lsmagic %include %use %saveAs

# %%
cube([10,10,10]);
# Out:
# Number of lines of OpenSCAD code: 2

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 1 elements
# Geometries in cache: 1
# Geometry cache size in bytes: 728
# CGAL Polyhedrons in cache: 0
# CGAL cache size in bytes: 0
# Total rendering time: 0:00:00.164

# %%
%saveAs /data/test.scad
# Out:
# File '/data/test.scad' created

# %%
%saveAs /data/test.stl
# Out:
# File '/data/test.stl' created

# %%
%displayCode
# Out:
# cube([10,10,10]);

# %%
%mime
# Out:
# The display mime type is 'image/png'

# %%
%%display
$fn=360;
cylinder(h=20,d=5);
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 2 elements
# Geometries in cache: 2
# Geometry cache size in bytes: 52720
# CGAL Polyhedrons in cache: 0
# CGAL cache size in bytes: 0
# Total rendering time: 0:00:00.158

# %%
%display
# Out:
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 1 elements
# Geometries in cache: 1
# Geometry cache size in bytes: 728
# CGAL Polyhedrons in cache: 0
# CGAL cache size in bytes: 0
# Total rendering time: 0:00:00.173
